# %%
import time
import math

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import time
#       2 import math
# ----> 4 import torch
#       5 import torch.nn as nn
#       6 import torch.nn.functional as F
#
# File /usr/local/lib/python3.10/dist-packages/torch/__init__.py:2680
#    2676 from torch.func import vmap as vmap
#    2679 if not TYPE_CHECKING:
# -> 2680     from torch import _meta_registrations
#    2682 # Enable CUDA Sanitizer
#    2683 if "TORCH_CUDA_SANITIZER" in os.environ:
#
# File /usr/local/lib/python3.10/dist-packages/torch/_meta_registrations.py:12
#      10 import torch._prims_common as utils
#      11 from torch import SymBool, SymFloat, Tensor
# ---> 12 from torch._decomp import (
#      13     _add_op_to_registry,
#      14     _convert_out_params,
#      15     global_decomposition_table,
#      16     meta_table,
#      17 )
#      18 from torch._ops import OpOverload
#      19 from torch._prims import _prim_elementwise_meta, ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND
#
# File /usr/local/lib/python3.10/dist-packages/torch/_decomp/__init__.py:276
#     272             decompositions.pop(op, None)
#     275 # populate the table
# --> 276 import torch._decomp.decompositions
#     277 import torch._refs
#     280 def core_aten_decompositions() -> "CustomDecompTable":
#
# File /usr/local/lib/python3.10/dist-packages/torch/_decomp/decompositions.py:16
#      14 import torch
#      15 import torch._meta_registrations
# ---> 16 import torch._prims as prims
#      17 import torch._prims_common as utils
#      18 import torch.nn.functional as F
#
# File /usr/local/lib/python3.10/dist-packages/torch/_prims/__init__.py:525
#     517     raise NotImplementedError
#     520 #
#     521 # Elementwise unary operations
#     522 #
# --> 525 abs = _make_elementwise_unary_prim(
#     526     "abs",
#     527     impl_aten=torch.abs,
#     528     doc="",
#     529     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.COMPLEX_TO_FLOAT,
#     530 )
#     532 acos = _make_elementwise_unary_prim(
#     533     "acos",
#     534     impl_aten=torch.acos,
#     535     doc="",
#     536     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     537 )
#     539 acosh = _make_elementwise_unary_prim(
#     540     "acosh",
#     541     impl_aten=torch.acosh,
#     542     doc="",
#     543     type_promotion=ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND.DEFAULT,
#     544 )
#
# File /usr/local/lib/python3.10/dist-packages/torch/_prims/__init__.py:493, in _make_elementwise_unary_prim(name, type_promotion, **kwargs)
#     486 def _make_elementwise_unary_prim(
#     487     name: str, *, type_promotion: ELEMENTWISE_PRIM_TYPE_PROMOTION_KIND, **kwargs
#     488 ):
#     489     """
#     490     Creates an elementwise unary prim.
#     491     """
# --> 493     return _make_prim(
#     494         schema=f"{name}(Tensor self) -> Tensor",
#     495         meta=partial(_prim_elementwise_meta, type_promotion=type_promotion),
#     496         return_type=RETURN_TYPE.NEW,
#     497         **kwargs,
#     498     )
#
# File /usr/local/lib/python3.10/dist-packages/torch/_prims/__init__.py:321, in _make_prim(schema, return_type, meta, impl_aten, doc, tags, use_old_custom_ops_api, register_conj_neg_fallthrough)
#     315 else:
#     316     mutates_args = [
#     317         arg.name
#     318         for arg in cpp_schema.arguments
#     319         if arg.alias_info is not None and arg.alias_info.is_write
#     320     ]
# --> 321     prim_def = torch.library.custom_op(
#     322         "prims::" + name,
#     323         _prim_impl,
#     324         mutates_args=tuple(mutates_args),
#     325         schema=schema,
#     326     )
#     327     prim_def.register_fake(meta)
#     329     # all view ops get conj/neg fallthroughs
#
# File /usr/local/lib/python3.10/dist-packages/torch/_library/custom_ops.py:172, in custom_op(name, fn, mutates_args, device_types, schema, tags)
#     170 if fn is None:
#     171     return inner
# --> 172 return inner(fn)
#
# File /usr/local/lib/python3.10/dist-packages/torch/_library/custom_ops.py:153, in custom_op.<locals>.inner(fn)
#     150     schema_str = schema
#     152 namespace, opname = name.split("::")
# --> 153 result = CustomOpDef(namespace, opname, schema_str, fn, tags)
#     154 if schema is not None:
#     155     # Check that schema's alias annotations match those of `mutates_args`.
#     156     expected = set()
#
# File /usr/local/lib/python3.10/dist-packages/torch/_library/custom_ops.py:211, in CustomOpDef.__init__(self, namespace, name, schema, fn, tags)
#     208 self._autocast_cpu_dtype: Optional[_dtype] = None
#     210 self._lib = get_library_allowing_overwrite(self._namespace, self._name)
# --> 211 self._register_to_dispatcher(self._tags)
#     212 self._disabled_kernel: set = set()
#     213 self._used_triton_kernels: list[Any] = list()
#
# File /usr/local/lib/python3.10/dist-packages/torch/_library/custom_ops.py:629, in CustomOpDef._register_to_dispatcher(self, tags)
#     621         raise RuntimeError(
#     622             f"There was no fake impl registered for {self}. "
#     623             f"This is necessary for torch.compile/export/fx tracing to work. "
#     624             f"Please use `{self._init_fn.__name__}.register_fake` to add an "
#     625             f"fake impl."
#     626         )
#     627     return self._abstract_fn(*args, **kwargs)
# --> 629 lib._register_fake(self._name, fake_impl, _stacklevel=4)
#     631 autograd_impl = autograd.make_autograd_impl(self._opoverload, self)
#     632 lib.impl(self._name, autograd_impl, "Autograd", with_keyset=True)
#
# File /usr/local/lib/python3.10/dist-packages/torch/library.py:190, in Library._register_fake(self, op_name, fn, _stacklevel, allow_override)
#     187 def _register_fake(self, op_name, fn, _stacklevel=1, *, allow_override=False):
#     188     r"""Registers the fake impl for an operator defined in the library."""
# --> 190     source = torch._library.utils.get_source(_stacklevel + 1)
#     191     frame = sys._getframe(_stacklevel)
#     192     caller_module = inspect.getmodule(frame)
#
# File /usr/local/lib/python3.10/dist-packages/torch/_library/utils.py:44, in get_source(stacklevel)
#      35 def get_source(stacklevel: int) -> str:
#      36     """Get a string that represents the caller.
#      37
#      38     Example: "/path/to/foo.py:42"
#    (...)
#      42     etc.
#      43     """
# ---> 44     frame = inspect.getframeinfo(sys._getframe(stacklevel))
#      45     source = f"{frame.filename}:{frame.lineno}"
#      46     return source
#
# File /usr/lib/python3.10/inspect.py:1624, in getframeinfo(frame, context)
#    1622 start = lineno - 1 - context//2
#    1623 try:
# -> 1624     lines, lnum = findsource(frame)
#    1625 except OSError:
#    1626     lines = index = None
#
# File /usr/lib/python3.10/inspect.py:952, in findsource(object)
#     949     if not (file.startswith('<') and file.endswith('>')):
#     950         raise OSError('source code not available')
# --> 952 module = getmodule(object, file)
#     953 if module:
#     954     lines = linecache.getlines(file, module.__dict__)
#
# File /usr/lib/python3.10/inspect.py:875, in getmodule(object, _filename)
#     873     continue
#     874 _filesbymodname[modname] = f
# --> 875 f = getabsfile(module)
#     876 # Always map to the name the module knows itself by
#     877 modulesbyfile[f] = modulesbyfile[
#     878     os.path.realpath(f)] = module.__name__
#
# File /usr/lib/python3.10/inspect.py:844, in getabsfile(object, _filename)
#     839 """Return an absolute path to the source or compiled file for an object.
#     840
#     841 The idea is for each object to have a unique origin, so this routine
#     842 normalizes the result as much as possible."""
#     843 if _filename is None:
# --> 844     _filename = getsourcefile(object) or getfile(object)
#     845 return os.path.normcase(os.path.abspath(_filename))
#
# File /usr/lib/python3.10/inspect.py:826, in getsourcefile(object)
#     823 elif any(filename.endswith(s) for s in
#     824              importlib.machinery.EXTENSION_SUFFIXES):
#     825     return None
# --> 826 if os.path.exists(filename):
#     827     return filename
#     828 # only return a non-existent filename if the module has a PEP 302 loader
#
# File /usr/lib/python3.10/genericpath.py:19, in exists(path)
#      17 """Test whether a path exists.  Returns False for broken symbolic links"""
#      18 try:
# ---> 19     os.stat(path)
#      20 except (OSError, ValueError):
#      21     return False
#
# KeyboardInterrupt:

# %%
batch_size_train = 128
batch_size_test = 1000

transform = transforms.ToTensor()

train_loader = DataLoader(
    datasets.MNIST('.', train=True, download=True, transform=transform),
    batch_size=batch_size_train,
    shuffle=True,
)

test_loader = DataLoader(
    datasets.MNIST('.', train=False, transform=transform),
    batch_size=batch_size_test,
    shuffle=False,
)

# %%
def lmul(a, b, M=7):
    """
    L-MUL approximation based on mantissa/exponent decomposition.
    a, b: tensors
    M: controls mantissa precision
    """
    a, b = a.float(), b.float()


    s1 = torch.sign(a)
    s2 = torch.sign(b)
    s = s1 * s2


    m1, e1 = torch.frexp(torch.abs(a))
    m2, e2 = torch.frexp(torch.abs(b))

    m1 = 2 * m1 - 1
    m2 = 2 * m2 - 1

 
    if M <= 3:
        L = M
    elif M == 4:
        L = 3
    else:
        L = 4

    bias = 1
    exponent = e1 + e2 - bias
    mantissa = 1 + m1 + m2 + 2**(-L)


    carry = (mantissa >= 2).float()
    mantissa = torch.where(carry == 1, mantissa / 2, mantissa)
    exponent = exponent + carry.long()

    out = s * torch.ldexp(mantissa, exponent)
    return out


def lmul_linear(x, W, b=None, M=7):
    """
    x: [B, D_in]
    W: [D_out, D_in]
    """
    B = x.shape[0]
    D_out, D_in = W.shape

    x_expanded = x.unsqueeze(1).expand(B, D_out, D_in)
    W_expanded = W.unsqueeze(0).expand(B, D_out, D_in)

    prod = lmul(x_expanded, W_expanded, M=M)
    out = prod.sum(dim=2)

    if b is not None:
        out = out + b

    return out



def lmul_conv2d(x, W, b=None, stride=1, padding=0, M=7):
    """
    x: [B, C_in, H, W]
    W: [C_out, C_in, kH, kW]
    """
    B, C_in, H, W_in = x.shape
    C_out, C_in_w, kH, kW = W.shape
    assert C_in == C_in_w, "Input channels mismatch"

    patches = F.unfold(x, kernel_size=(kH, kW),
                       padding=padding, stride=stride)
    K = patches.size(1)
    L = patches.size(2)

    patches = patches.transpose(1, 2)
    W_flat = W.view(C_out, -1)


    a = patches.unsqueeze(1) 
    bW = W_flat.unsqueeze(0).unsqueeze(2) 
    prod = lmul(a, bW, M=M)  

    out = prod.sum(dim=3) 

    H_out = int((H + 2*padding - kH) / stride + 1)
    W_out = int((W_in + 2*padding - kW) / stride + 1)
    out = out.view(B, C_out, H_out, W_out)

    if b is not None:
        out = out + b.view(1, -1, 1, 1)

    return out

# %%
class CNN(nn.Module):
    def __init__(self, use_lmul=False, M=7):
        super().__init__()
        self.use_lmul = use_lmul
        self.M = M


        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, stride=1, padding=1)
        self.fc1 = nn.Linear(64 * 7 * 7, 128)
        self.fc2 = nn.Linear(128, 10)

    def forward(self, x):
        if not self.use_lmul:

            x = F.relu(self.conv1(x))
            x = F.max_pool2d(x, 2)

            x = F.relu(self.conv2(x))
            x = F.max_pool2d(x, 2)

            x = x.view(x.size(0), -1)

            x = F.relu(self.fc1(x))
            x = self.fc2(x)

        else:

            x = lmul_conv2d(x, self.conv1.weight, self.conv1.bias,
                            stride=1, padding=1, M=self.M)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)

            x = lmul_conv2d(x, self.conv2.weight, self.conv2.bias,
                            stride=1, padding=1, M=self.M)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)

            x = x.view(x.size(0), -1)

            x = F.relu(lmul_linear(x, self.fc1.weight,
                                   self.fc1.bias, M=self.M))
            x = lmul_linear(x, self.fc2.weight, self.fc2.bias, M=self.M)

        return F.log_softmax(x, dim=1)

# %%
def train_model(model, optimizer, loader, epochs=1):
    model.train()
    for ep in range(epochs):
        total = 0
        correct = 0
        for x, y in loader:
            x, y = x.to(device), y.to(device)

            optimizer.zero_grad()
            out = model(x)
            loss = F.nll_loss(out, y)
            loss.backward()
            optimizer.step()

            pred = out.argmax(dim=1)
            total += y.size(0)
            correct += (pred == y).sum().item()

        print(f"Epoch {ep+1}/{epochs} – loss: {loss:.4f}, acc: {correct/total:.4f}")


def test_acc(model, loader):
    model.eval()
    total = 0
    correct = 0
    with torch.no_grad():
        for x, y in loader:
            x, y = x.to(device), y.to(device)
            out = model(x)
            pred = out.argmax(dim=1)
            total += y.size(0)
            correct += (pred == y).sum().item()
    return 100.0 * correct / total

# %%
baseline_model = CNN(use_lmul=False, M=7).to(device)
optimizer = torch.optim.Adam(baseline_model.parameters(), lr=1e-3)

start = time.perf_counter()
train_model(baseline_model, optimizer, train_loader, epochs=5)
baseline_time = time.perf_counter() - start

baseline_acc = test_acc(baseline_model, test_loader)

print("\nBaseline CNN accuracy (MNIST): {:.2f}%".format(baseline_acc))
print("Baseline total time (train+test): {:.2f} s".format(baseline_time))


lmul_model = CNN(use_lmul=True, M=7).to(device)
lmul_model.load_state_dict(baseline_model.state_dict())

start = time.perf_counter()
lmul_acc = test_acc(lmul_model, test_loader)
lmul_time = time.perf_counter() - start

print("\nLMUL CNN accuracy (MNIST): {:.2f}%".format(lmul_acc))
print("LMUL evaluation time: {:.4f} s".format(lmul_time))
# Out:
# Epoch 1/5 – loss: 0.0910, acc: 0.9283
# Epoch 2/5 – loss: 0.0621, acc: 0.9811
# Epoch 3/5 – loss: 0.0205, acc: 0.9868
# Epoch 4/5 – loss: 0.0271, acc: 0.9893
# Epoch 5/5 – loss: 0.0493, acc: 0.9913
#
# Baseline CNN accuracy (MNIST): 98.94%
# Baseline total time (train+test): 78.43 s
