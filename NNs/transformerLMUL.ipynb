# %%
#using this library to load all dependencies for link below (nanoGPT)
#!pip install torch numpy transformers datasets tiktoken wandb tqdm
#https://github.com/karpathy/nanoGPT
#run this, then restart the kernel. Our environment is run on a slightly older pytorch but this numpy came out in 2024
#The reason this isn't in the dockerfile is to prevent interference with the default environment
# !pip uninstall -y numpy
# !pip install "numpy<2"

# %%
# !python3 data/shakespeare_char/prepare.py
# Out:
# length of dataset in characters: 1,115,394
# all the unique characters:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocab size: 65
# train has 1,003,854 tokens
# val has 111,540 tokens

# %%
#DO NOT RUN THIS AGAIN; only run this IF and ONLY IF you do not have a trained GPT. 
#!python3 train_nano.py config/train_shakespeare_char.py

# %%
import torch
# we want a "True 1" result 
print(torch.cuda.is_available())
print(torch.cuda.device_count())
# Out:
# False
# 0

# %%
# !pip install torch numpy datasets tiktoken wandb tqdm
# !pip install "transformers<4.36"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in /home/blkuang/.local/lib/python3.11/site-packages (2.4.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: datasets in /opt/conda/lib/python3.11/site-packages (3.0.0)
# Requirement already satisfied: tiktoken in /home/blkuang/.local/lib/python3.11/site-packages (0.12.0)
# Requirement already satisfied: wandb in /home/blkuang/.local/lib/python3.11/site-packages (0.24.0)
# Requirement already satisfied: tqdm in /home/blkuang/.local/lib/python3.11/site-packages (4.67.0)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/blkuang/.local/lib/python3.11/site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.11/site-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.11/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.11/site-packages (from torch) (3.1.3)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.11/site-packages (from torch) (2024.3.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/blkuang/.local/lib/python3.11/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /opt/conda/lib/python3.11/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /opt/conda/lib/python3.11/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /opt/conda/lib/python3.11/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/blkuang/.local/lib/python3.11/site-packages (from torch) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /opt/conda/lib/python3.11/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.0.0 in /home/blkuang/.local/lib/python3.11/site-packages (from torch) (3.0.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /opt/conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.1.105)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/blkuang/.local/lib/python3.11/site-packages (from datasets) (21.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/blkuang/.local/lib/python3.11/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/lib/python3.11/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: xxhash in /opt/conda/lib/python3.11/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /opt/conda/lib/python3.11/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp in /home/blkuang/.local/lib/python3.11/site-packages (from datasets) (3.11.13)
# Requirement already satisfied: huggingface-hub>=0.22.0 in /home/blkuang/.local/lib/python3.11/site-packages (from datasets) (0.35.3)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.11/site-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/blkuang/.local/lib/python3.11/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: regex>=2022.1.18 in /opt/conda/lib/python3.11/site-packages (from tiktoken) (2024.9.11)
# Requirement already satisfied: click>=8.0.1 in /opt/conda/lib/python3.11/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/blkuang/.local/lib/python3.11/site-packages (from wandb) (3.1.44)
# Requirement already satisfied: platformdirs in /home/blkuang/.local/lib/python3.11/site-packages (from wandb) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /opt/conda/lib/python3.11/site-packages (from wandb) (4.25.4)
# Requirement already satisfied: pydantic<3 in /home/blkuang/.local/lib/python3.11/site-packages (from wandb) (2.12.3)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /home/blkuang/.local/lib/python3.11/site-packages (from wandb) (2.49.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/blkuang/.local/lib/python3.11/site-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: propcache>=0.2.0 in /home/blkuang/.local/lib/python3.11/site-packages (from aiohttp->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/blkuang/.local/lib/python3.11/site-packages (from aiohttp->datasets) (1.22.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.11/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/blkuang/.local/lib/python3.11/site-packages (from huggingface-hub>=0.22.0->datasets) (1.1.10)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/blkuang/.local/lib/python3.11/site-packages (from pydantic<3->wandb) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /home/blkuang/.local/lib/python3.11/site-packages (from pydantic<3->wandb) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/blkuang/.local/lib/python3.11/site-packages (from pydantic<3->wandb) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.11/site-packages (from jinja2->torch) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets) (2.9.0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.11/site-packages (from sympy->torch) (1.3.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.11/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: transformers<4.36 in /home/blkuang/.local/lib/python3.11/site-packages (4.35.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.11/site-packages (from transformers<4.36) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /home/blkuang/.local/lib/python3.11/site-packages (from transformers<4.36) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/lib/python3.11/site-packages (from transformers<4.36) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.11/site-packages (from transformers<4.36) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/blkuang/.local/lib/python3.11/site-packages (from transformers<4.36) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.11/site-packages (from transformers<4.36) (2024.9.11)
# Requirement already satisfied: requests in /opt/conda/lib/python3.11/site-packages (from transformers<4.36) (2.32.3)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/blkuang/.local/lib/python3.11/site-packages (from transformers<4.36) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.11/site-packages (from transformers<4.36) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in /home/blkuang/.local/lib/python3.11/site-packages (from transformers<4.36) (4.67.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers<4.36) (2024.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/blkuang/.local/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers<4.36) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /home/blkuang/.local/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.16.4->transformers<4.36) (1.1.10)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.11/site-packages (from requests->transformers<4.36) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.11/site-packages (from requests->transformers<4.36) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.11/site-packages (from requests->transformers<4.36) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.11/site-packages (from requests->transformers<4.36) (2024.8.30)

# %%
# !CUDA_LAUNCH_BLOCKING=1. python3 sample.py --out_dir=out-shakespeare-char
# Out:
# Overriding: out_dir = out-shakespeare-char
# /home/blkuang/.local/lib/python3.11/site-packages/torch/amp/autocast_mode.py:265: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Using device: cpu
# /home/blkuang/private/lmul/180b/NNs/sample.py:39: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location=device)
# starting up!
# using LMUL in CasualSelfAttention Layer!
# using LMUL in MLP!
# using LMUL in CasualSelfAttention Layer!
# using LMUL in MLP!
# using LMUL in CasualSelfAttention Layer!
# using LMUL in MLP!
# using LMUL in CasualSelfAttention Layer!
# using LMUL in MLP!
# using LMUL in CasualSelfAttention Layer!
# using LMUL in MLP!
# using LMUL in CasualSelfAttention Layer!
# using LMUL in MLP!
# using LMUL in GPT lm head!
# number of parameters: 10.65M
# Loading meta from data/shakespeare_char/meta.pkl...
# No CUDA runtime is found, using CUDA_HOME='/opt/conda'
#
# VIRGILIA:
# O, shot a troth!
#
# VOLUMNIA:
# Yes, then, I'll speak on the good bawd, but having hath
# raiste
# ---------------

# %%
#!pip uninstall torch torchvision torchaudio -y
#!pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu130

# %%
import torch
print(torch.version.cuda)       
print(torch.cuda.is_available()) 
print(torch.cuda.get_device_name(0))
# Out:
# 12.1
# True
# NVIDIA GeForce RTX 3060 Laptop GPU

# %%
# !python3 eval_perplexity.py --out_dir=out-shakespeare-char
# Out:
# Using LMUL: False
# /home/blkuang/private/lmul/180b/NNs/eval_perplexity.py:36: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location=device)
# starting up!
# LMUL HAS BEEN DISABLED
# number of parameters: 10.65M
# No CUDA runtime is found, using CUDA_HOME='/opt/conda'
# Validation loss: 1.6064
# Validation perplexity: 4.99

# %%
# !python3 eval_perplexity.py --out_dir=out-shakespeare-char --use_lmul
# Out:
# Using LMUL: True
# Using | block_size: 32 | num_batches: 50 | batch_size: 4
#  ==> For a total of 6400 tokens, or 32 tokens per sequence among 200 sequences
# /home/blkuang/private/lmul/180b/NNs/eval_perplexity.py:37: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location=device)
# starting up!
# using LMUL in CasualSelfAttention Layer!
# using LMUL in MLP!
# using LMUL in CasualSelfAttention Layer!
# using LMUL in MLP!
# using LMUL in CasualSelfAttention Layer!
# using LMUL in MLP!
# using LMUL in CasualSelfAttention Layer!
# using LMUL in MLP!
# using LMUL in CasualSelfAttention Layer!
# using LMUL in MLP!
# using LMUL in CasualSelfAttention Layer!
# using LMUL in MLP!
# using LMUL in GPT lm head!
# number of parameters: 10.65M
# No CUDA runtime is found, using CUDA_HOME='/opt/conda'
# Validation loss: 1.5350
# Validation perplexity: 4.64
