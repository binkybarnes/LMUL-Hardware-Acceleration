# %%
#using this library to load all dependencies for link below (nanoGPT)
#!pip install torch numpy transformers datasets tiktoken wandb tqdm
#https://github.com/karpathy/nanoGPT
#run this, then restart the kernel. Our environment is run on a slightly older pytorch but this numpy came out in 2024
#The reason this isn't in the dockerfile is to prevent interference with the default environment
# !pip uninstall -y numpy
# !pip install "numpy<2"

# %%
# !python3 data/shakespeare_char/prepare.py
# Out:
# length of dataset in characters: 1,115,394
# all the unique characters:
#  !$&',-.3:;?ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghijklmnopqrstuvwxyz
# vocab size: 65
# train has 1,003,854 tokens
# val has 111,540 tokens

# %%
#DO NOT RUN THIS AGAIN; only run this IF and ONLY IF you do not have a trained GPT. 
#!python3 train_nano.py config/train_shakespeare_char.py

# %%
import torch
# we want a "True 1" result 
print(torch.cuda.is_available())
print(torch.cuda.device_count())
# Out:
# False
# 0

# %%
#!pip install torch numpy datasets tiktoken wandb tqdm
#!pip install "transformers<4.36"

# %%
#!CUDA_LAUNCH_BLOCKING=1. python3 sample.py --out_dir=out-shakespeare-char
# !CUDA_LAUNCH_BLOCKING=1. python3 sample.py --out_dir=OWT --start="The real problem with this country is"
# Out:
# Overriding: out_dir = OWT
# Overriding: start = The real problem with this country is
# /home/blkuang/.local/lib/python3.11/site-packages/torch/amp/autocast_mode.py:265: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Using device: cpu
# ...

# %%
#!pip uninstall torch torchvision torchaudio -y
#!pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu130

# %%
import torch
print(torch.version.cuda)       
print(torch.cuda.is_available()) 
print(torch.cuda.get_device_name(0))
# Out:
# 12.1
# True
# NVIDIA GeForce RTX 3060 Laptop GPU

# %%
# !python3 eval_perplexity.py --out_dir=out-shakespeare-char
# Out:
# Using LMUL: False
# Using | block_size: 32 | num_batches: 50 | batch_size: 4
#  ==> For a total of 6400 tokens, or 32 tokens per sequence among 200 sequences
# ...

# %%
# !python3 eval_perplexity.py --out_dir=out-shakespeare-char --use_lmul
# Out:
# Using LMUL: True
# Using | block_size: 32 | num_batches: 50 | batch_size: 4
#  ==> For a total of 6400 tokens, or 32 tokens per sequence among 200 sequences
# ...

# %%
# !python3 eval_perplexity.py --out_dir=out-shakespeare-char --use_lmul --panel 110
# Out:
# Using LMUL: True
# Using | block_size: 32 | num_batches: 50 | batch_size: 4
#  ==> For a total of 6400 tokens, or 32 tokens per sequence among 200 sequences
# ...

# %%
# !python3 eval_perplexity.py --out_dir=out-shakespeare-char --use_lmul --panel 100
# Out:
# Using LMUL: True
# Using | block_size: 32 | num_batches: 50 | batch_size: 4
#  ==> For a total of 6400 tokens, or 32 tokens per sequence among 200 sequences
# ...

# %%
# !python3 eval_perplexity.py --out_dir=out-shakespeare-char --use_lmul --panel 011
# Out:
# Using LMUL: True
# Using | block_size: 32 | num_batches: 50 | batch_size: 4
#  ==> For a total of 6400 tokens, or 32 tokens per sequence among 200 sequences
# ...

# %%
# !python3 eval_perplexity.py --out_dir=out-shakespeare-char --use_lmul --panel 010
# Out:
# Using LMUL: True
# Using | block_size: 32 | num_batches: 50 | batch_size: 4
#  ==> For a total of 6400 tokens, or 32 tokens per sequence among 200 sequences
# ...

# %%
#https://www.kaggle.com/datasets/carrot1500/openwebtext-data-prepared-for-nanogpt?resource=download&select=val.bin
# !python3 eval_OWT.py --out_dir=OWT --OWT
# Out:
# /home/blkuang/private/lmul/180b/NNs/eval_OWT.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location=device)
# starting up!
# ...

# %%
# !python3 eval_OWT.py --out_dir=OWT --OWT
# Out:
# /home/blkuang/private/lmul/180b/NNs/eval_OWT.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location=device)
# starting up!
# ...

# %%
# !python3 eval_OWT.py --out_dir=OWT --OWT --use_lmul
# Out:
# /home/blkuang/private/lmul/180b/NNs/eval_OWT.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location=device)
# starting up!
# ...

# %%
# !python3 eval_OWT.py --out_dir=OWT --OWT
# Out:
# /home/blkuang/private/lmul/180b/NNs/eval_OWT.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location=device)
# starting up!
# ...

# %%
# !python3 eval_OWT.py --out_dir=OWT --OWT --use_lmul
# Out:
# /home/blkuang/private/lmul/180b/NNs/eval_OWT.py:45: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location=device)
# starting up!
# ...

# %%
# !python3 eval_OWT.py --out_dir=OWT --OWT
# Out:
# /home/blkuang/private/lmul/180b/NNs/eval_OWT.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location=device)
# starting up!
# ...

# %%
# !python3 eval_OWT.py --out_dir=OWT --OWT --use_lmul
# Out:
# /home/blkuang/private/lmul/180b/NNs/eval_OWT.py:53: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(ckpt_path, map_location=device)
# starting up!
# ...

# %%
# !CUDA_LAUNCH_BLOCKING=1 USE_LMUL=1  python3 sample.py --out_dir=OWT --start="The real problem with this country is"
# Out:
# ***USING LMUL
# Overriding: out_dir = OWT
# Overriding: start = The real problem with this country is
# /home/blkuang/.local/lib/python3.11/site-packages/torch/amp/autocast_mode.py:265: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Using device: cpu
# ...

# %%
# !CUDA_LAUNCH_BLOCKING=1 USE_LMUL=1  python3 sample.py --out_dir=OWT --start="The real problem with this country is"
# Out:
# ***USING LMUL
# Overriding: out_dir = OWT
# Overriding: start = The real problem with this country is
# /home/blkuang/.local/lib/python3.11/site-packages/torch/amp/autocast_mode.py:265: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn(
# Using device: cpu
# ...

# %%
import torch
ckpt = torch.load("OWT/ckpt.pt", map_location="cpu")
print(ckpt["model_args"])
print(len(ckpt["model"]))
# Out:
# /tmp/ipykernel_1048/1354716962.py:2: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   ckpt = torch.load("OWT/ckpt.pt", map_location="cpu")
# ...
